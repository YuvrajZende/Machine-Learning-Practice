# %% [markdown]
# <a href="https://colab.research.google.com/github/YuvrajZende/Machine-Learning-Practice/blob/main/B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.impute import SimpleImputer
import numpy as np

data = [[2, 4, np.nan],
        [np.nan, 1, 5],
        [3, np.nan, 6]]

imputer = SimpleImputer(strategy='mean')
imputed_data = imputer.fit_transform(data)

print(data)
print(imputed_data)
# Out:
# [[2, 4, nan], [nan, 1, 5], [3, nan, 6]]
# [[2.  4.  5.5]
#  [2.5 1.  5. ]
#  [3.  2.5 6. ]]

# %%
from sklearn.impute import KNNImputer
import numpy as np

data = [[3, 1, np.nan, 4],
        [np.nan, 4, 5, 7],
        [3, np.nan, 4, 9]]

knn_imputer = KNNImputer(n_neighbors=2)
imputed_data = knn_imputer.fit_transform(data)

print(data)
print(imputed_data)
# Out:
# [[3, 1, nan, 4], [nan, 4, 5, 7], [3, nan, 4, 9]]
# [[3.  1.  4.5 4. ]
#  [3.  4.  5.  7. ]
#  [3.  2.5 4.  9. ]]
